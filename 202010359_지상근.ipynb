# %% [markdown]
# <a href="https://colab.research.google.com/github/laners01/2-2-dataprogramming/blob/main/202010359_%EC%A7%80%EC%83%81%EA%B7%BC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 새 섹션

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
from sklearn.model_selection import train_test_split

plt.rc('font', family='NanumBarunGothic')

df = pd.read_csv("/content/sample_data/방송통신위원회_해외방송시장조사_OTT 서비스 시청 비율_20220711.csv", encoding='cp949')

df_age = df.loc[df["구분"] == "10대"]

df_twenty = df.loc[df["구분"] == "20대"]
df_age = df_age.append(df_twenty, ignore_index=True)

df_thirty = df.loc[df["구분"] == "30대"]
df_age = df_age.append(df_thirty, ignore_index=True)

df_fourty = df.loc[df["구분"] == "40대"]
df_age = df_age.append(df_fourty, ignore_index=True)

df_fifty = df.loc[df["구분"] == "50대 이상"]
df_age = df_age.append(df_fifty, ignore_index=True)

sns.barplot(x="구분", y="예(비율)", data=df_age)
plt.ylabel("시청 비율")
plt.xlabel("나이대")
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 24 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# ...

# %%
df_income= df.loc[df["구분"] == "3,000$ 미만"]

df_5000 = df.loc[df["구분"] == "3,000$~5,000$ 미만"]
df_income = df_income.append(df_5000, ignore_index=True)

df_7000 = df.loc[df["구분"] == "5,000$~7,000$ 미만"]
df_income = df_income.append(df_7000, ignore_index=True)

df_10000 = df.loc[df["구분"] == "7,000$ 이상~10,000$ 미만"]
df_income = df_income.append(df_10000, ignore_index=True)

df_over = df.loc[df["구분"] == "10,000$ 이상"]
df_income = df_income.append(df_over, ignore_index=True)

sns.barplot(x="구분", y="예(비율)", data=df_income)
plt.ylabel("시청 비율")
plt.xlabel("소득 수준")
# Out:
# <ipython-input-55-18b53c45a979>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_income = df_income.append(df_5000, ignore_index=True)
# <ipython-input-55-18b53c45a979>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_income = df_income.append(df_7000, ignore_index=True)
# <ipython-input-55-18b53c45a979>:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_income = df_income.append(df_10000, ignore_index=True)
# <ipython-input-55-18b53c45a979>:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_income = df_income.append(df_over, ignore_index=True)
# Text(0.5, 0, '소득 수준')
# ...

# %%
df_sch = df.loc[df["구분"] == "고졸 이하"]

df_ovr = df.loc[df["구분"] == "대졸 이상"]
df_sch = df_sch.append(df_ovr, ignore_index=True)

sns.barplot(x="구분", y="예(비율)", data=df_sch)
plt.ylabel("시청 비율")
plt.xlabel("최종 학력")
# Out:
# <ipython-input-129-b93b13a0e573>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_sch = df_sch.append(df_ovr, ignore_index=True)
# Text(0.5, 0, '최종 학력')

# %%
df2 = pd.read_csv("/content/sample_data/방송통신위원회_OTT 서비스 이용 시 즐겨보는 장르_20220711.csv",encoding='cp949')

df_teen2 = df2.loc[df2["구분"] == "10대"]
df_teen2 = df_teen2.loc[: , '구분':'기타(비율)']
df_avg = pd.DataFrame({'구분':['평균'],'드라마':[11.20],"버라이어티쇼":[4.80],"음악":[6.81], "뉴스시사보도":[2.29],"교육": [2.56], "영화": [23.85], "스포츠":[4.52], "다큐멘터리":[2.52],"애니메이션": [9.01],"코미디": [14.29], "문화예술":[1.46],"퀴즈쇼게임쇼": [1.15], "토크쇼":[2.41],"키즈": [2.44],"리얼리티쇼": [4.16],"종교": [0.00],"생활": [0.21],"시리즈물": [0.42],"기타": [0.36]})
df_avg.plot(x="구분", y=["드라마","버라이어티쇼","음악","뉴스시사보도","교육","영화","스포츠","다큐멘터리","애니메이션","코미디","문화예술","퀴즈쇼게임쇼","토크쇼","키즈","리얼리티쇼","종교","생활","시리즈물","기타"], kind = "bar")
plt.show()

# %%
df_teen2.mean(numeric_only=True)
# Out:
# 사례수(명)        43.60
# 드라마(비율)       11.20
# 버라이어티쇼(비율)     4.80
# 음악(비율)         6.81
# 뉴스시사보도(비율)     2.29
# 교육(비율)         2.56
# 영화(비율)        23.85
# 스포츠(비율)        4.52
# 다큐멘터리(비율)      2.52
# 애니메이션(비율)      9.01
# 코미디(비율)       14.29
# 문화예술(비율)       1.46
# 퀴즈쇼게임쇼(비율)     1.15
# 토크쇼(비율)        2.41
# 키즈(비율)         2.44
# 리얼리티쇼(비율)      4.16
# 종교(비율)         0.00
# 생활(비율)         0.21
# 시리즈물(비율)       0.42
# 기타(비율)         0.36
# dtype: float64

# %%
df_twenty2 = df2.loc[df2["구분"] == "20대"]
df_twenty2 = df_twenty2.loc[: , '구분':'기타(비율)']
df_avg = pd.DataFrame({'구분':['평균'],'드라마':[15.08],"버라이어티쇼":[5.10],"음악":[3.68], "뉴스시사보도":[4.37],"교육": [2.11], "영화": [25.93], "스포츠":[7.43], "다큐멘터리":[5.51],"애니메이션": [4.78],"코미디": [11.08], "문화예술":[0.30],"퀴즈쇼게임쇼": [1.99], "토크쇼":[1.41],"키즈": [1.31],"리얼리티쇼": [4.25],"종교": [0.70],"생활": [0.00],"시리즈물": [0.38],"기타": [0.34]})
df_avg.plot(x="구분", y=["드라마","버라이어티쇼","음악","뉴스시사보도","교육","영화","스포츠","다큐멘터리","애니메이션","코미디","문화예술","퀴즈쇼게임쇼","토크쇼","키즈","리얼리티쇼","종교","생활","시리즈물","기타"], kind = "bar")
plt.show()

# %%
df_twenty2.mean(numeric_only=True)
# Out:
# 사례수(명)        69.50
# 드라마(비율)       15.08
# 버라이어티쇼(비율)     5.10
# 음악(비율)         3.68
# 뉴스시사보도(비율)     4.37
# 교육(비율)         2.11
# 영화(비율)        25.93
# 스포츠(비율)        7.43
# 다큐멘터리(비율)      5.51
# 애니메이션(비율)      4.78
# 코미디(비율)       11.08
# 문화예술(비율)       0.30
# 퀴즈쇼게임쇼(비율)     1.99
# 토크쇼(비율)        1.41
# 키즈(비율)         1.31
# 리얼리티쇼(비율)      4.25
# 종교(비율)         0.70
# 생활(비율)         0.00
# 시리즈물(비율)       0.38
# 기타(비율)         0.34
# dtype: float64

# %%
df_thirty2 = df2.loc[df2["구분"] == "30대"]
df_thirty2 = df_thirty2.loc[: , '구분':'기타(비율)']
df_avg = pd.DataFrame({'구분':['평균'],'드라마':[11.62],"버라이어티쇼":[5.58],"음악":[4.21], "뉴스시사보도":[7.23],"교육": [2.59], "영화": [24.22], "스포츠":[9.70], "다큐멘터리":[4.80],"애니메이션": [2.54],"코미디": [10.74], "문화예술":[0.75],"퀴즈쇼게임쇼": [0.15], "토크쇼":[1.85],"키즈": [3.93],"리얼리티쇼": [3.33],"종교": [0.88],"생활": [0.00],"시리즈물": [0.71],"기타": [0.29]})
df_avg.plot(x="구분", y=["드라마","버라이어티쇼","음악","뉴스시사보도","교육","영화","스포츠","다큐멘터리","애니메이션","코미디","문화예술","퀴즈쇼게임쇼","토크쇼","키즈","리얼리티쇼","종교","생활","시리즈물","기타"], kind = "bar")
plt.show()

# %%
df_thirty2.mean(numeric_only=True)
# Out:
# 사례수(명)        72.60
# 드라마(비율)       11.62
# 버라이어티쇼(비율)     5.58
# 음악(비율)         4.21
# 뉴스시사보도(비율)     7.23
# 교육(비율)         2.59
# 영화(비율)        24.22
# 스포츠(비율)        9.70
# 다큐멘터리(비율)      4.80
# 애니메이션(비율)      2.54
# 코미디(비율)       10.74
# 문화예술(비율)       0.75
# 퀴즈쇼게임쇼(비율)     0.15
# 토크쇼(비율)        1.85
# 키즈(비율)         3.93
# 리얼리티쇼(비율)      3.33
# 종교(비율)         0.88
# 생활(비율)         0.00
# 시리즈물(비율)       0.71
# 기타(비율)         0.29
# dtype: float64

# %%
df_fourty2 = df2.loc[df2["구분"] == "40대"]
df_fourty2 = df_fourty2.loc[: , '구분':'기타(비율)']
df_avg = pd.DataFrame({'구분':['평균'],'드라마':[12.37],"버라이어티쇼":[4.46],"음악":[5.53], "뉴스시사보도":[7.53],"교육": [1.40], "영화": [30.01], "스포츠":[9.63], "다큐멘터리":[4.89],"애니메이션": [1.39],"코미디": [8.39], "문화예술":[0.55],"퀴즈쇼게임쇼": [0.49], "토크쇼":[1.00],"키즈": [3.15],"리얼리티쇼": [4.23],"종교": [0.46],"생활": [0.00],"시리즈물": [0.38],"기타": [0.35]})
df_avg.plot(x="구분", y=["드라마","버라이어티쇼","음악","뉴스시사보도","교육","영화","스포츠","다큐멘터리","애니메이션","코미디","문화예술","퀴즈쇼게임쇼","토크쇼","키즈","리얼리티쇼","종교","생활","시리즈물","기타"], kind = "bar")
plt.show()

# %%
df_fourty2.mean(numeric_only=True)
# Out:
# 사례수(명)        64.30
# 드라마(비율)       12.37
# 버라이어티쇼(비율)     4.46
# 음악(비율)         5.53
# 뉴스시사보도(비율)     7.53
# 교육(비율)         1.40
# 영화(비율)        30.01
# 스포츠(비율)        9.63
# 다큐멘터리(비율)      4.89
# 애니메이션(비율)      1.39
# 코미디(비율)        8.39
# 문화예술(비율)       0.55
# 퀴즈쇼게임쇼(비율)     0.49
# 토크쇼(비율)        1.00
# 키즈(비율)         3.15
# 리얼리티쇼(비율)      4.23
# 종교(비율)         0.46
# 생활(비율)         0.00
# 시리즈물(비율)       0.38
# 기타(비율)         0.35
# dtype: float64

# %%
df_fifty2 = df2.loc[df2["구분"] == "50대 이상"]
df_fifty2 = df_fifty2.loc[: , '구분':'기타(비율)']
df_avg = pd.DataFrame({'구분':['평균'],'드라마':[12.31],"버라이어티쇼":[3.99],"음악":[5.95], "뉴스시사보도":[11.76],"교육": [2.62], "영화": [27.94], "스포츠":[9.15], "다큐멘터리":[5.47],"애니메이션": [1.41],"코미디": [6.26], "문화예술":[0.62],"퀴즈쇼게임쇼": [0.28], "토크쇼":[2.05],"키즈": [0.72],"리얼리티쇼": [2.33],"종교": [0.80],"생활": [0.34],"시리즈물": [0.21],"기타": [0.00]})
df_avg.plot(x="구분", y=["드라마","버라이어티쇼","음악","뉴스시사보도","교육","영화","스포츠","다큐멘터리","애니메이션","코미디","문화예술","퀴즈쇼게임쇼","토크쇼","키즈","리얼리티쇼","종교","생활","시리즈물","기타"], kind = "bar")
plt.show()

# %%
df_fifty2.mean(numeric_only=True)
# Out:
# 사례수(명)        74.20
# 드라마(비율)       12.31
# 버라이어티쇼(비율)     3.99
# 음악(비율)         5.95
# 뉴스시사보도(비율)    11.76
# 교육(비율)         2.62
# 영화(비율)        27.94
# 스포츠(비율)        9.15
# 다큐멘터리(비율)      5.47
# 애니메이션(비율)      1.41
# 코미디(비율)        6.26
# 문화예술(비율)       0.62
# 퀴즈쇼게임쇼(비율)     0.28
# 토크쇼(비율)        2.05
# 키즈(비율)         0.72
# 리얼리티쇼(비율)      2.33
# 종교(비율)         0.80
# 생활(비율)         0.34
# 시리즈물(비율)       0.21
# 기타(비율)         0.00
# dtype: float64

# %%
df_3000 = df2.loc[df2["구분"] == "3,000$ 미만"]
df_3000 = df_3000.loc[: , '구분':'기타(비율)']
df_avg = pd.DataFrame({'구분':['평균'],'드라마':[17.9],"버라이어티쇼":[7.1], "뉴스시사보도":[7.1],"교육":[0.0], "영화": [35.7], "스포츠":[7.1], "다큐멘터리":[1.8],"애니메이션": [23.2]})
df_avg.plot(x="구분", y=["드라마","버라이어티쇼","뉴스시사보도","교육","영화","스포츠","다큐멘터리","애니메이션"],title="3,000$ 미만", kind = "bar")
plt.show()

# %%
df_3000.mean(numeric_only=True)
# Out:
# 사례수(명)        56.0
# 드라마(비율)       17.9
# 버라이어티쇼(비율)     7.1
# 음악(비율)         0.0
# 뉴스시사보도(비율)     7.1
# 교육(비율)         0.0
# 영화(비율)        35.7
# 스포츠(비율)        7.1
# 다큐멘터리(비율)      1.8
# 애니메이션(비율)     23.2
# 코미디(비율)        0.0
# 문화예술(비율)       0.0
# 퀴즈쇼게임쇼(비율)     0.0
# 토크쇼(비율)        0.0
# 키즈(비율)         0.0
# 리얼리티쇼(비율)      0.0
# 종교(비율)         0.0
# 생활(비율)         0.0
# 시리즈물(비율)       0.0
# 기타(비율)         0.0
# dtype: float64

# %%
df_5000_2 = df2.loc[df2["구분"] == "3,000$~5,000$ 미만"]
df_5000_2 = df_5000_2.loc[: , '구분':'기타(비율)']
df_avg = pd.DataFrame({'구분':['평균'],'드라마':[29.5],"버라이어티쇼":[8.2], "뉴스시사보도":[8.2],"교육":[0.0], "영화": [29.5], "스포츠":[9.8], "다큐멘터리":[3.3],"애니메이션": [11.5]})
df_avg.plot(x="구분", y=["드라마","버라이어티쇼","뉴스시사보도","교육","영화","스포츠","다큐멘터리","애니메이션"],title="3,000$ 이상~5,000$ 미만", kind = "bar")
plt.show()
# Out:
# WARNING:matplotlib.mathtext:Font 'rm' does not have a glyph for '\uc774' [U+c774], substituting with a dummy symbol.
# WARNING:matplotlib.mathtext:Font 'rm' does not have a glyph for '\uc0c1' [U+c0c1], substituting with a dummy symbol.
# WARNING:matplotlib.mathtext:Font 'rm' does not have a glyph for '\uc774' [U+c774], substituting with a dummy symbol.
# WARNING:matplotlib.mathtext:Font 'rm' does not have a glyph for '\uc0c1' [U+c0c1], substituting with a dummy symbol.

# %%
df_5000_2.mean(numeric_only=True)
# Out:
# 사례수(명)        61.0
# 드라마(비율)       29.5
# 버라이어티쇼(비율)     8.2
# 음악(비율)         0.0
# 뉴스시사보도(비율)     8.2
# 교육(비율)         0.0
# 영화(비율)        29.5
# 스포츠(비율)        9.8
# 다큐멘터리(비율)      3.3
# 애니메이션(비율)     11.5
# 코미디(비율)        0.0
# 문화예술(비율)       0.0
# 퀴즈쇼게임쇼(비율)     0.0
# 토크쇼(비율)        0.0
# 키즈(비율)         0.0
# 리얼리티쇼(비율)      0.0
# 종교(비율)         0.0
# 생활(비율)         0.0
# 시리즈물(비율)       0.0
# 기타(비율)         0.0
# dtype: float64

# %%
df_7000_2 = df2.loc[df2["구분"] == "5,000$~7,000$ 미만"]
df_7000_2 = df_7000_2.loc[: , '구분':'기타(비율)']
df_avg = pd.DataFrame({'구분':['평균'],'드라마':[20.0],"버라이어티쇼":[14.5], "뉴스시사보도":[5.5],"교육":[1.8], "영화": [40.0], "스포츠":[9.1], "다큐멘터리":[1.8],"애니메이션": [7.3]})
df_avg.plot(x="구분", y=["드라마","버라이어티쇼","뉴스시사보도","교육","영화","스포츠","다큐멘터리","애니메이션"],title="5,000$ 이상~7,000$ 미만", kind = "bar")
plt.show()

# %%
df_7000_2.mean(numeric_only=True)
# Out:
# 사례수(명)        55.0
# 드라마(비율)       20.0
# 버라이어티쇼(비율)    14.5
# 음악(비율)         0.0
# 뉴스시사보도(비율)     5.5
# 교육(비율)         1.8
# 영화(비율)        40.0
# 스포츠(비율)        9.1
# 다큐멘터리(비율)      1.8
# 애니메이션(비율)      7.3
# 코미디(비율)        0.0
# 문화예술(비율)       0.0
# 퀴즈쇼게임쇼(비율)     0.0
# 토크쇼(비율)        0.0
# 키즈(비율)         0.0
# 리얼리티쇼(비율)      0.0
# 종교(비율)         0.0
# 생활(비율)         0.0
# 시리즈물(비율)       0.0
# 기타(비율)         0.0
# dtype: float64

# %%
df_10000_2 = df2.loc[df2["구분"] == "7,000$ 이상~10,000$ 미만"]
df_10000_2 = df_10000_2.loc[: , '구분':'기타(비율)']
df_avg = pd.DataFrame({'구분':['평균'],'드라마':[22.2],"버라이어티쇼":[9.7], "뉴스시사보도":[19.4],"교육":[2.8], "영화": [25.0], "스포츠":[9.7], "다큐멘터리":[5.6],"애니메이션": [5.6]})
df_avg.plot(x="구분", y=["드라마","버라이어티쇼","뉴스시사보도","교육","영화","스포츠","다큐멘터리","애니메이션"],title="7,000$ 이상~10,000$ 미만", kind = "bar")
plt.show()
# Out:
# WARNING:matplotlib.mathtext:Font 'rm' does not have a glyph for '\uc774' [U+c774], substituting with a dummy symbol.
# WARNING:matplotlib.mathtext:Font 'rm' does not have a glyph for '\uc0c1' [U+c0c1], substituting with a dummy symbol.
# WARNING:matplotlib.mathtext:Font 'rm' does not have a glyph for '\uc774' [U+c774], substituting with a dummy symbol.
# WARNING:matplotlib.mathtext:Font 'rm' does not have a glyph for '\uc0c1' [U+c0c1], substituting with a dummy symbol.

# %%
df_10000_2.mean(numeric_only=True)
# Out:
# 사례수(명)        72.0
# 드라마(비율)       22.2
# 버라이어티쇼(비율)     9.7
# 음악(비율)         0.0
# 뉴스시사보도(비율)    19.4
# 교육(비율)         2.8
# 영화(비율)        25.0
# 스포츠(비율)        9.7
# 다큐멘터리(비율)      5.6
# 애니메이션(비율)      5.6
# 코미디(비율)        0.0
# 문화예술(비율)       0.0
# 퀴즈쇼게임쇼(비율)     0.0
# 토크쇼(비율)        0.0
# 키즈(비율)         0.0
# 리얼리티쇼(비율)      0.0
# 종교(비율)         0.0
# 생활(비율)         0.0
# 시리즈물(비율)       0.0
# 기타(비율)         0.0
# dtype: float64

# %%
df_over_2 = df2.loc[df2["구분"] == "10,000$ 이상"]
df_over_2 = df_over_2.loc[: , '구분':'기타(비율)']
df_avg = pd.DataFrame({'구분':['평균'],'드라마':[24.1],"버라이어티쇼":[8.0], "뉴스시사보도":[19.5],"교육":[4.6], "영화": [27.6], "스포츠":[8.0], "다큐멘터리":[1.1],"애니메이션": [6.9]})
df_avg.plot(x="구분", y=["드라마","버라이어티쇼","뉴스시사보도","교육","영화","스포츠","다큐멘터리","애니메이션"], title="10,000$ 이상",kind = "bar")
plt.show()

# %%
df_over_2.mean(numeric_only=True)
# Out:
# 사례수(명)        87.0
# 드라마(비율)       24.1
# 버라이어티쇼(비율)     8.0
# 음악(비율)         0.0
# 뉴스시사보도(비율)    19.5
# 교육(비율)         4.6
# 영화(비율)        27.6
# 스포츠(비율)        8.0
# 다큐멘터리(비율)      1.1
# 애니메이션(비율)      6.9
# 코미디(비율)        0.0
# 문화예술(비율)       0.0
# 퀴즈쇼게임쇼(비율)     0.0
# 토크쇼(비율)        0.0
# 키즈(비율)         0.0
# 리얼리티쇼(비율)      0.0
# 종교(비율)         0.0
# 생활(비율)         0.0
# 시리즈물(비율)       0.0
# 기타(비율)         0.0
# dtype: float64

# %%
df_und = df2.loc[df2["구분"] == "고졸 이하"]
df_und = df_und.loc[: , '구분':'기타(비율)']
df_avg = pd.DataFrame({'구분':['평균'],'드라마':[13.97],"버라이어티쇼":[4.45],"음악":[6.23], "뉴스시사보도":[4.87],"교육": [2.21], "영화": [24.60], "스포츠":[7.02], "다큐멘터리":[3.68],"애니메이션": [6.50],"코미디": [9.71], "문화예술":[0.71],"퀴즈쇼게임쇼": [0.77], "토크쇼":[1.68],"키즈": [2.43],"리얼리티쇼": [4.24],"종교": [0.69],"생활": [0.08],"시리즈물": [0.31],"기타": [0.39]})
df_avg.plot(x="구분", y=["드라마","버라이어티쇼","음악","뉴스시사보도","교육","영화","스포츠","다큐멘터리","애니메이션","코미디","문화예술","퀴즈쇼게임쇼","토크쇼","키즈","리얼리티쇼","종교","생활","시리즈물","기타"],title="고졸 이하", kind = "bar")
plt.show()

# %%
df_und.mean(numeric_only=True)
# Out:
# 사례수(명)        94.50
# 드라마(비율)       13.97
# 버라이어티쇼(비율)     4.45
# 음악(비율)         6.23
# 뉴스시사보도(비율)     4.87
# 교육(비율)         2.21
# 영화(비율)        24.60
# 스포츠(비율)        7.02
# 다큐멘터리(비율)      3.68
# 애니메이션(비율)      6.50
# 코미디(비율)        9.71
# 문화예술(비율)       0.71
# 퀴즈쇼게임쇼(비율)     0.77
# 토크쇼(비율)        1.68
# 키즈(비율)         2.43
# 리얼리티쇼(비율)      4.24
# 종교(비율)         0.69
# 생활(비율)         0.08
# 시리즈물(비율)       0.31
# 기타(비율)         0.39
# dtype: float64

# %%
df_ovr2 = df2.loc[df2["구분"] == "대졸 이상"]
df_ovr2 = df_ovr2.loc[: , '구분':'기타(비율)']
df_avg = pd.DataFrame({'구분':['평균'],'드라마':[11.47],"버라이어티쇼":[5.01],"음악":[5.07], "뉴스시사보도":[7.07],"교육": [2.40], "영화": [26.27], "스포츠":[8.88], "다큐멘터리":[6.00],"애니메이션": [1.62],"코미디": [10.61], "문화예술":[0.74],"퀴즈쇼게임쇼": [0.84], "토크쇼":[1.88],"키즈": [2.73],"리얼리티쇼": [3.71],"종교": [0.67],"생활": [0.17],"시리즈물": [0.53],"기타": [0.22]})
df_avg.plot(x="구분", y=["드라마","버라이어티쇼","음악","뉴스시사보도","교육","영화","스포츠","다큐멘터리","애니메이션","코미디","문화예술","퀴즈쇼게임쇼","토크쇼","키즈","리얼리티쇼","종교","생활","시리즈물","기타"],title="대졸 이상", kind = "bar")
plt.show()

# %%
df_ovr2.mean(numeric_only=True)
# Out:
# 사례수(명)        225.000000
# 드라마(비율)        11.466667
# 버라이어티쇼(비율)      4.233333
# 음악(비율)          5.066667
# 뉴스시사보도(비율)      7.066667
# 교육(비율)          2.400000
# 영화(비율)         26.266667
# 스포츠(비율)         8.877778
# 다큐멘터리(비율)       6.000000
# 애니메이션(비율)       1.622222
# 코미디(비율)        10.611111
# 문화예술(비율)        0.744444
# 퀴즈쇼게임쇼(비율)      0.844444
# 토크쇼(비율)         1.877778
# 키즈(비율)          2.733333
# 리얼리티쇼(비율)       3.711111
# 종교(비율)          0.666667
# 생활(비율)          0.166667
# 시리즈물(비율)        0.533333
# 기타(비율)          0.222222
# dtype: float64
